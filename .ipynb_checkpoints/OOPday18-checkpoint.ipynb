# %%
class Person:
    name=None
    age=None
    gender=None

# %%
p1 = Person()

# %%
print(p1.name)
# Out:
# None

# %%
p1.name = "Hem"

# %%
print(p1.name)
# Out:
# Hem

# %%
p2 = Person()

# %%
print(p2.gender)
# Out:
# None

# %%
p2.gender = 23

# %%
print(p2.gender)
# Out:
# 23

# %%
class Person2:
    def __init__(self):
        self.name = None
        self.age = None
        self.gender = None

# %%
p1 = Person2()

# %%
print(p1.name)
# Out:
# None

# %%
p1.name = "Raj"

# %%
print(p1.name)
# Out:
# Raj

# %%
class Person3:
    def __init__(self):
        self.name = None
        self.age = None
        self.gender = None

    def set_name(self,name,age):
        self.name= name
        self.age = age

# %%
p1 = Person3()

# %%
print(p1.name)
# Out:
# None

# %%
p1.set_name('Ram',12)

# %%
print(p1.name)
# Out:
# Ram

# %%
print(p1.age)
# Out:
# 12

# %%
p2=Person()

# %%
print(p2.gender)
# Out:
# None

# %%
class Person3:
    name_attr='Hem'
    def __init__(self,name_val,age_val):
        self.name = name_val
        self.age = age_val

    def get_data(self,gender_val=23):
        gender = gender_val
        return f"{self.name_attr}"

    def get_data2(self, gender3=28):
        global gender
        gender = gender3
        print (gender)

# %%
p1 = Person3(name_val="Rajan",age_val=23)

# %%
p1.get_data()
# Out:
# 'Hem'

# %%
p1.get_data2()
# Out:
# 28
