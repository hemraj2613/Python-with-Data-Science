# %%
# methods(function)
def add():
    return 2+3
add()
# Out:
# 5

# %%
def add(a,b,c):
    return a+b+c
add(2,3,4)
print("Sum of 10,20,30 is: ",add(10,20,30))
# Out:
# Sum of 10,20,30 is:  60

# %%
def div(x,y):
    return x/y
z = div(10,5)
print("Divison is ",z)
# Out:
# Divison is  2.0

# %%
def sub(x,y):
    return x-y
z= sub(20,10)
print("Subtraction is",z)
# Out:
# Subtraction is 10
