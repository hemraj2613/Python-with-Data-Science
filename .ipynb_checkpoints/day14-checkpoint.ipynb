# %%
# local variables
# a variable whose scope is only inside a particular function
def num():
    a = 20 #local variable
    print(a)
num()
# Out:
# 20

# %%
# global varibale
b=3
print(b)
# Out:
# 3

# %%
def num1():
    global b
    b=12
    print(b)

num1()
# Out:
# 12

# %%
def num2():
    print(b)

num2()
# Out:
# 12

# %%
print(b)
# Out:
# 12

# %%
def funcs():
    return "Hem",29,[2,4,5]

funcs()
# Out:
# ('Hem', 29, [2, 4, 5])

# %%
a,b,c = funcs()

# %%
a
# Out:
# 'Hem'

# %%
b
# Out:
# 29

# %%
c
# Out:
# [2, 4, 5]
