# %%
# isinstance used for proper validation
isinstance(19, int)
# Out:
# True

# %%
isinstance("a", str)
# Out:
# True

# %%
print(isinstance(10, float))
# Out:
# False

# %%
var = "Hemraj Ojha"
len(var)
# Out:
# 11

# %%
var = "\t"
len(var)
# Out:
# 1

# %%
var = "\n"
len(var)
# Out:
# 1

# %%
name = "Hemraj Ojha"
name[-1]
# Out:
# 'a'

# %%
name[-4]
# Out:
# 'O'

# %%
name[:6]
# Out:
# 'Hemraj'

# %%
name[:5]
# Out:
# 'Hemra'

# %%
name[:-3]
# Out:
# 'Hemraj O'

# %%
# [start_index:end_index]

# %%
name[3:]
# Out:
# 'raj Ojha'

# %%
name[3:10]
# Out:
# 'raj Ojh'

# %%
name[-4:]
# Out:
# 'Ojha'

# %%
# name[::]
# [start_index:last_index:step]
print(name)
name[3:6:1]
# Out:
# Hemraj Ojha
# 'raj'

# %%
# mutable == changable
# immutable == can't changed value directly once assigned

# %%
name
# Out:
# 'Hemraj Ojha'

# %%
name.replace("H", "Y")
name.replace("He","Ya")
# Out:
# 'Yamraj Ojha'

# %%
name.replace("a", "s")
# Out:
# 'Hemrsj Ojhs'

# %%
# string

# %%
text1="hem"
text2="raj"

# %%
print(text1+text2)
# Out:
# hemraj

# %%
print(text1 + " " + text2)
# Out:
# hem raj

# %%
name.split()
# Out:
# ['Hemraj', 'Ojha']

# %%
list(name)
# Out:
# ['H', 'e', 'm', 'r', 'a', 'j', ' ', 'O', 'j', 'h', 'a']

# %%
name = "hemraj"
name
# Out:
# 'hemraj'

# %%
print(name.upper())
# Out:
# HEMRAJ

# %%
name.lower()
# Out:
# 'hemraj'

# %%
name.title()
# Out:
# 'Hemraj'

# %%
'hemraj ojha'.title()
# Out:
# 'Hemraj Ojha'

# %%
# split
"Hemraj#Ojha" .split('#')
# Out:
# ['Hemraj', 'Ojha']

# %%
'hem#raj#ojha'.replace('#'," ")
# Out:
# 'hem raj ojha'

# %%
# join
' '.join('hem#raj#ojha'.split('#'))
# Out:
# 'hem raj ojha'

# %%
' '.join('hem#raj#ojha'.replace('#', " "))
# Out:
# 'h e m   r a j   o j h a'

# %%
# string and integer will not concatenated and joined
'a' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 2
#       1 # string and integer are not concatenate
# ----> 2 'a' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
# type conversion
a = 10
type(a)
# Out:
# int

# %%
float(a)
# Out:
# 10.0

# %%
str(a)
# Out:
# '10'

# %%
bool(a)
# Out:
# True

# %%
b = 2.44
type(b)
# Out:
# float

# %%
int(b)
# Out:
# 2

# %%
str(b)
# Out:
# '2.44'

# %%
text = 'a1'
type(text)
# Out:
# str

# %%
int(text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 int(text)
#
# ValueError: invalid literal for int() with base 10: 'a1'
