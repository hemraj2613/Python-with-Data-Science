# %%
# External packages: pre implemented python code by someone

# %%
import pandas as pd

# %%
# 1. create a dataframe
pd.DataFrame(
    rows and columns
)

# %%
pd.DataFrame(
    {
        "col1" : [1,2,3],
        "col2" : ['a','b','c']
    }
)
# Out:
#    col1 col2
# 0     1    a
# 1     2    b
# 2     3    c

# %%
pd.DataFrame(
    {
        "col1" : [1,2,3,4],
        "col2" : ('a','b','c','d'),
        "col3" : "hemr"
    }
)
# Out:
#    col1 col2  col3
# 0     1    a  hemr
# 1     2    b  hemr
# 2     3    c  hemr
# 3     4    d  hemr

# %%
data = {
        "col1" : [1,2,3,4],
        "col2" : ('a','b','c','d'),
        "col3" : "hemr"
    }
pd.DataFrame(
    data
)
# Out:
#    col1 col2  col3
# 0     1    a  hemr
# 1     2    b  hemr
# 2     3    c  hemr
# 3     4    d  hemr

# %%
df = pd.DataFrame(
    {
        "col1" : [1,2,3,4],
        "col2" : ('a','b','c','d'),
    }
)

# %%
df
# Out:
#    col1 col2
# 0     1    a
# 1     2    b
# 2     3    c
# 3     4    d

# %%
df['col3'] = [12,13,15,12]

# %%
df
# Out:
#    col1 col2  col3
# 0     1    a    12
# 1     2    b    13
# 2     3    c    15
# 3     4    d    12

# %%
df.values
# Out:
# array([[1, 'a', 12],
#        [2, 'b', 13],
#        [3, 'c', 15],
#        [4, 'd', 12]], dtype=object)

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='str')

# %%
df.col2
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# Name: col2, dtype: str

# %%
df.col3[2]
# Out:
# np.int64(15)

# %%
# indexing
1. loc
2. iloc
