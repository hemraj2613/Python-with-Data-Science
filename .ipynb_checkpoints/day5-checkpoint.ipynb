# %%
laptop = {'brand':"Dell",'processor':"Intel Core",'RAM':"16GB"}
print(laptop)
# Out:
# {'brand': 'Dell', 'processor': 'Intel Core', 'RAM': '16GB'}

# %%
laptop['brand']
# Out:
# 'Dell'

# %%
len(laptop)
# Out:
# 3

# %%
a={}
a["name"]="Hem"
a
# Out:
# {'name': 'Hem'}

# %%
a["age"]=23
a
# Out:
# {'name': 'Hem', 'age': 23}

# %%
a["name"] = a["name"].upper()
print(a)
# Out:
# {'name': 'HEM', 'age': 23}

# %%
x = dict(a=1,b=2,c=3,d=4)
print(x)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
x.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
x.values()
# Out:
# dict_values([1, 2, 3, 4])

# %%
len(x)
# Out:
# 4

# %%
print(x.get("e"))
# Out:
# None

# %%
print(x.get("e", "not provided"))
# Out:
# not provided

# %%
# nested dict
nested = {"user":{"name":"hem"}}
nested.get("user",{}).get("email","not found")
# Out:
# 'not found'

# %%
x={'a':1,'b':2,'c':3}
if "a" in x:
    print(x['b'])
# Out:
# 2

# %%
item = {'name':"rice", 'price':290, 'Dis_Price':50, 'tax' :500}
print(item['price'])
# Out:
# 290

# %%
item ={}
item['price'] = 1000
tax = 500
discount = 40
item['price']= item['price']+tax-discount
print(item)
# Out:
# {'price': 1460}

# %%
item['discount'] = discount
item['tax'] = tax
print(item)
# Out:
# {'price': 1460, 'discount': 40, 'tax': 500}

# %%
# nested dictionary

items = {
"item1":{'name':'watch','price':1200,'data':[1,2,3,{'data1':[1,2,3]}]},
"item2":{'name':'mobile','price':12000}
}
print(items)
# Out:
# {'item1': {'name': 'watch', 'price': 1200, 'data': [1, 2, 3, {'data1': [1, 2, 3]}]}, 'item2': {'name': 'mobile', 'price': 12000}}

# %%
print(items['item1'])
# Out:
# {'name': 'watch', 'price': 1200, 'data': [1, 2, 3, {'data1': [1, 2, 3]}]}

# %%
print(items['item1']['name'])
# Out:
# watch

# %%
len(items)
# Out:
# 2

# %%
items['item1']['data'][3]['data1'][2]
# Out:
# 3

# %%
items.get('item1').get('data')[3].get('data1')[2]
# Out:
# 3

# %%
len(items['item1'])
# Out:
# 3

# %%
len(items['item1']['data'])
# Out:
# 4
