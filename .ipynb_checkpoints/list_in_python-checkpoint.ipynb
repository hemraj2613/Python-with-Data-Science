# %%
list_num = [1,2,3,4]
list_num
# Out:
# [1, 2, 3, 4]

# %%
type(list_num)
# Out:
# list

# %%
a = ['a', 'b', 'c']
# indexing in list
a[0]
a[-1]
# Out:
# 'c'

# %%
# slicing is used for multiple items
a[0:2]
# Out:
# ['a', 'b']

# %%
a1 = ['a','b','c','d','e','f']
a1
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
a1[1:3]
# Out:
# ['b', 'c']

# %%
a1[-1:]
# Out:
# ['f']

# %%
a1[1:-3]
# Out:
# ['b', 'c']

# %%
# steps in list
# [start_index: end_index: steps]
a1[0:3:2]
# Out:
# ['a', 'c']

# %%
# changing the list items (list are mutable)
players = ['hem', 'raj', 'dammar','naresh']
players[0] = 'hemant'
print(players)
# Out:
# ['hemant', 'raj', 'dammar', 'naresh']

# %%
print(players)
'hem' in players
# Out:
# ['hemant', 'raj', 'dammar', 'naresh']
# False

# %%
# concatenate 
a= [1,2,3]
b=[4,5,6]
a+b
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a2 = [1,2,3,"a","b","c"]
a2
# Out:
# [1, 2, 3, 'a', 'b', 'c']

# %%
a2 = a2+["d"]+["e"]
a2
# Out:
# [1, 2, 3, 'a', 'b', 'c', 'd', 'd', 'e']

# %%
a2+a2
# Out:
# [1, 2, 3, 'a', 'b', 'c', 'd', 'd', 'e', 1, 2, 3, 'a', 'b', 'c', 'd', 'd', 'e']

# %%
a = [1,2,3]
a = a*2
print(a)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
a = [1,2,3,4,5]
a+[9]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a = a+[9]
a
# Out:
# [1, 2, 3, 4, 5, 9]

# %%
a+=[10]
a
# Out:
# [1, 2, 3, 4, 5, 9, 10]

# %%
# apppend is used to add element at last
a=[1,2,3,4]
a.append([12])

# %%
a
# Out:
# [1, 2, 3, 4, [12]]

# %%
# insert is used to add element at certain position
a.insert(2,'a')
print(a)
# Out:
# [1, 2, 'a', 3, 4, [12]]
