# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl

# %%
df = pd.read_csv('nepal_students_dataset.csv')

# %%
df = df.head(10)
df
# Out:
#    student_id       province  gender  age  study_hours_per_week  \
# 0           1        Lumbini  Female   15                  17.0
# 1           2        Bagmati  Female   16                  11.0
# 2           3        Karnali    Male   16                  13.5
# 3           4        Lumbini    Male   15                   2.4
# 4           5          Koshi    Male   17                   7.4
# 5           6  Sudurpashchim    Male   16                  10.8
# 6           7        Lumbini    Male   15                   7.7
# 7           8        Lumbini  Female   16                  14.9
# 8           9          Koshi    Male   15                  20.0
# 9          10        Bagmati    Male   17                   7.3
#
#    attendance_percent  family_income_npr internet_access  math_marks  \
# 0                88.2              24200             Yes          49
# 1                85.5              14600             Yes          45
# ...

# %%
# matplotlib

# %%
# scatter

pl.figure(figsize=(7,5))
pl.title("Study hours vs Math marks")
pl.xlabel("Study Hours")
pl.ylabel("Marks obtained in Mathematics")
pl.scatter(df["study_hours_per_week"],df["math_marks"] , c='red', marker='*')
pl.grid()
pl.show()

# %%
df = pd.read_csv('nepal_students_dataset.csv')

# %%
df
# Out:
#      student_id province  gender  age  study_hours_per_week  \
# 0             1  Lumbini  Female   15                  17.0
# 1             2  Bagmati  Female   16                  11.0
# 2             3  Karnali    Male   16                  13.5
# 3             4  Lumbini    Male   15                   2.4
# 4             5    Koshi    Male   17                   7.4
# ..          ...      ...     ...  ...                   ...
# 195         196  Madhesh    Male   15                  13.0
# 196         197  Gandaki  Female   16                  17.4
# 197         198  Karnali    Male   15                  12.0
# 198         199  Madhesh    Male   17                  12.8
# 199         200  Madhesh    Male   15                   7.6
#
#      attendance_percent  family_income_npr internet_access  math_marks  \
# 0                  88.2              24200             Yes          49
# 1                  85.5              14600             Yes          45
# ...

# %%
province_value_count = df['province'].value_counts()

# %%
province_value_count
# Out:
# province
# Bagmati          46
# Madhesh          39
# Lumbini          38
# Koshi            33
# Gandaki          19
# Sudurpashchim    16
# Karnali           9
# Name: count, dtype: int64

# %%
province_value_count.values
# Out:
# array([46, 39, 38, 33, 19, 16,  9])

# %%
x =province_value_count.keys()
height = province_value_count.values

# %%
height
# Out:
# array([46, 39, 38, 33, 19, 16,  9])

# %%
# bargraph
pl.figure(figsize=(10,4))
pl.title("Province name and data count")
pl.xlabel("Province Name")
pl.ylabel("Data Count")
pl.bar(x,height, label="Data Count", color="orange", edgecolor="black", alpha=0.5)
pl.legend()
pl.xticks(rotation=45)
# pl.yticks([0, 50, 100, 150, 200])
# pl.xlim(0, 5)
pl.show()

# %%
subject = ["Math","Science","English","Nepali"]
marks = [40,65,32,99]
pl.bar(subject,marks,width=0.2 ,color=["orange","red","teal","black"],edgecolor="black")
pl.title("Marks vs Subject", color="teal", fontsize=26)
pl.xlabel("Subject")
pl.ylabel("Marks Obtained")
pl.xticks(rotation=45)
pl.show()

# %%
male_counts = df["gender"].value_counts()

# %%
male_counts
# Out:
# gender
# Male      101
# Female     99
# Name: count, dtype: int64

# %%
x = male_counts.keys()
x
# Out:
# Index(['Male', 'Female'], dtype='str', name='gender')

# %%
height = male_counts.values
height
# Out:
# array([101,  99])

# %%
pl.title("Male vs Female")
pl.xlabel("Gender")
pl.ylabel("Numbers")
pl.bar(x,height,color=["red","orange"])
pl.show()

# %%
male_sum = df["study_hours_per_week"].sum()
# Out:
# np.float64(2348.7)

# %%
pl.title("Ratio of male and female data counts")
pl.pie(height, labels=x, autopct="%1.1f%%")
pl.show()

# %%
# groupby
df.groupby('gender')['study_hours_per_week'].sum()
# Out:
# gender
# Female    1195.6
# Male      1153.1
# Name: study_hours_per_week, dtype: float64

# %%
province_wise_income = df.groupby('province')['family_income_npr'].sum()

# %%
province_wise_income
# Out:
# province
# Bagmati          1414300
# Gandaki           631300
# Karnali           304200
# Koshi            1045600
# Lumbini          1239700
# Madhesh          1377200
# Sudurpashchim     689800
# Name: family_income_npr, dtype: int64

# %%
x = province_wise_income.keys()
x
# Out:
# Index(['Bagmati', 'Gandaki', 'Karnali', 'Koshi', 'Lumbini', 'Madhesh',
#        'Sudurpashchim'],
#       dtype='str', name='province')

# %%
height = province_wise_income.values
height
# Out:
# array([1414300,  631300,  304200, 1045600, 1239700, 1377200,  689800])

# %%
pl.title("Province vs Monthly Family income")
pl.pie(height,labels=x , autopct="%0.1f")
pl.show()

# %%
pl.title("Province vs Monthly Family income")
pl.xlabel("Province")
pl.ylabel("Family income")
pl.bar(x,height)
pl.xticks(rotation =45)
pl.show()

# %%
province_gender_wise_income = df.groupby(['province','gender'])['family_income_npr'].sum()

# %%
province_gender_wise_income
# Out:
# province       gender
# Bagmati        Female    791300
#                Male      623000
# Gandaki        Female    316600
#                Male      314700
# Karnali        Female     99700
#                Male      204500
# Koshi          Female    573700
#                Male      471900
# Lumbini        Female    500200
#                Male      739500
# Madhesh        Female    729100
#                Male      648100
# Sudurpashchim  Female    411700
#                Male      278100
# Name: family_income_npr, dtype: int64

# %%
x = province_gender_wise_income.keys()

# %%
y = province_gender_wise_income.values

# %%
# pl.title("Province & Gender vs Family income")
# pl.xlabel("Province & Gender")
# pl.ylabel("Family income")
# pl.bar(x,y)

# %%
df.groupby(['province','gender'])['family_income_npr'].sum().plot(kind='bar')
pl.show()

# %%
province_wise_income = df.groupby('province')['family_income_npr'].sum()

# %%
pl.figure(figsize=(7,5))
pl.title("Province vs Family income")
# pl.xlabel("Province")
# pl.ylabel("Family income")
pl.plot(province_wise_income, c='red', marker='*')
pl.grid()
pl.show()

# %%
# boxplot
student_age = [23,43,-42,56,76]
pl.boxplot(student_age)
pl.show()
