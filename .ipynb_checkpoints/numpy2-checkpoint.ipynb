# %%
import numpy as np

# %%
a = np.array([[2,3,4],[5,6,7]])

# %%
a
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
a.flatten()
# Out:
# array([2, 3, 4, 5, 6, 7])

# %%
a.T
# Out:
# array([[2, 5],
#        [3, 6],
#        [4, 7]])

# %%
a
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
a.sum()
# Out:
# np.int64(27)

# %%
a.mean()
# Out:
# np.float64(4.5)

# %%
a.max(axis=0)
# Out:
# array([5, 6, 7])

# %%
a.min()
# Out:
# np.int64(2)

# %%
a.std()
# Out:
# np.float64(1.707825127659933)

# %%
a.sum(axis=0)
# Out:
# array([ 7,  9, 11])

# %%
a.sum(axis=1)
# Out:
# array([ 9, 18])

# %%
a
# Out:
# array([[2, 3, 4],
#        [5, 6, 7]])

# %%
b = np.array([1,3,2,6,4])

# %%
b
# Out:
# array([1, 3, 2, 6, 4])

# %%
np.sort(b)
# Out:
# array([1, 2, 3, 4, 6])

# %%
b
# Out:
# array([1, 2, 3, 4, 6])

# %%
a = np.array([[20,3,2],[5,60,7]])
a
# Out:
# array([[20,  3,  2],
#        [ 5, 60,  7]])

# %%
a.sort(axis=0)

# %%
a
# Out:
# array([[ 5,  3,  2],
#        [20, 60,  7]])

# %%
a.sort(axis=1)

# %%
a
# Out:
# array([[ 2,  3,  5],
#        [ 7, 20, 60]])

# %%
a
# Out:
# array([[ 2,  3,  5],
#        [ 7, 20, 60]])

# %%
c = np.array([[20,3,2,34],[5,60,7,21]])
c
# Out:
# array([[20,  3,  2, 34],
#        [ 5, 60,  7, 21]])

# %%
c<10
# Out:
# array([[False,  True,  True, False],
#        [ True, False,  True, False]])

# %%
c[c<10]
# Out:
# array([1, 4, 5])

# %%
c = np.array([1,31,4,5,90,64])

# %%
c
# Out:
# array([ 1, 31,  4,  5, 90, 64])

# %%
c[(c<10) | (c>60)]
# Out:
# array([ 1,  4,  5, 90, 64])

# %%
a = np.array([1,31,4,5,90,64])
b = np.array([11,10,3,2,11,4])
c = np.array([13,12,3,2,11,4])

# %%
np.concat([a,b])
# Out:
# array([ 1, 31,  4,  5, 90, 64, 11, 10,  3,  2, 11,  4])

# %%
np.concatenate([a,b])
# Out:
# array([ 1, 31,  4,  5, 90, 64, 11, 10,  3,  2, 11,  4])

# %%
np.vstack([a,b,c])
# Out:
# array([[ 1, 31,  4,  5, 90, 64],
#        [11, 10,  3,  2, 11,  4],
#        [13, 12,  3,  2, 11,  4]])

# %%
np.hstack([a,b])
# Out:
# array([ 1, 31,  4,  5, 90, 64, 11, 10,  3,  2, 11,  4])

# %%
np.random.rand(20)
# Out:
# array([0.34529746, 0.79658868, 0.44614623, 0.78274941, 0.99047178,
#        0.30024834, 0.14300583, 0.90130844, 0.54155938, 0.97474037,
#        0.6366044 , 0.99391302, 0.5460708 , 0.52642593, 0.1354279 ,
#        0.35570517, 0.02621857, 0.16039518, 0.74563719, 0.03039969])

# %%
np.random.randint(1,10,5)
# Out:
# array([7, 5, 3, 3, 7], dtype=int32)

# %%
np.random.seed(1)
np.random.randint(100,200,8)
# Out:
# array([137, 112, 172, 109, 175, 105, 179, 164], dtype=int32)

# %%
np.random.random_sample(20)
# Out:
# array([0.74382585, 0.19542948, 0.58135893, 0.97001999, 0.8468288 ,
#        0.23984776, 0.49376971, 0.61995572, 0.8289809 , 0.15679139,
#        0.0185762 , 0.07002214, 0.48634511, 0.60632946, 0.56885144,
#        0.31736241, 0.98861615, 0.57974522, 0.38014117, 0.55094822])
