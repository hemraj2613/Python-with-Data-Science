# %%
import pandas as pd

# %%
df=pd.read_excel('Product-Sales-Region.xlsx')

# %%
df.head()
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 0 2023-02-23     East  Laptop        14     163.60       Store B    Wholesale
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
# 4 2023-06-24     East    Desk        18     237.76       Store C       Retail
#
#    Discount Salesperson  TotalPrice PaymentMethod Promotion  Returned  \
# 0      0.00         Eva    2290.400        Online  FREESHIP         0
# 1      0.00       Alice     544.010     Gift Card    SAVE10         0
# 2      0.10       Alice    4361.868        Online  WINTER15         0
# 3      0.15       Frank    5887.746     Gift Card  FREESHIP         0
# 4      0.00      Carlos    4279.680        Online    SAVE10         0
#
# ...

# %%
df.shape
# Out:
# (1500, 19)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1500 non-null   datetime64[us]
#  1   Region         1500 non-null   str
#  2   Product        1500 non-null   str
#  3   Quantity       1500 non-null   int64
#  4   UnitPrice      1500 non-null   float64
#  5   StoreLocation  1500 non-null   str
#  6   CustomerType   1500 non-null   str
#  7   Discount       1500 non-null   float64
#  8   Salesperson    1500 non-null   str
#  9   TotalPrice     1500 non-null   float64
#  10  PaymentMethod  1500 non-null   str
#  11  Promotion      1130 non-null   str
#  12  Returned       1500 non-null   int64
#  13  OrderID        1500 non-null   str
#  14  CustomerName   1500 non-null   str
#  15  ShippingCost   1500 non-null   float64
#  16  OrderDate      1500 non-null   datetime64[us]
#  17  DeliveryDate   1500 non-null   datetime64[us]
# ...

# %%
df['product_total_price'] = df['Quantity']*df['UnitPrice']

# %%
df.head()
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 0 2023-02-23     East  Laptop        14     163.60       Store B    Wholesale
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
# 4 2023-06-24     East    Desk        18     237.76       Store C       Retail
#
#    Discount Salesperson  TotalPrice PaymentMethod Promotion  Returned  \
# 0      0.00         Eva    2290.400        Online  FREESHIP         0
# 1      0.00       Alice     544.010     Gift Card    SAVE10         0
# 2      0.10       Alice    4361.868        Online  WINTER15         0
# 3      0.15       Frank    5887.746     Gift Card  FREESHIP         0
# 4      0.00      Carlos    4279.680        Online    SAVE10         0
#
# ...

# %%
df['revenue'] = df['product_total_price']-df['Discount']-df['ShippingCost']

# %%
df.head()
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 0 2023-02-23     East  Laptop        14     163.60       Store B    Wholesale
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
# 4 2023-06-24     East    Desk        18     237.76       Store C       Retail
#
#    Discount Salesperson  TotalPrice  ... Promotion Returned    OrderID  \
# 0      0.00         Eva    2290.400  ...  FREESHIP        0  REG100000
# 1      0.00       Alice     544.010  ...    SAVE10        0  REG100001
# 2      0.10       Alice    4361.868  ...  WINTER15        0  REG100002
# 3      0.15       Frank    5887.746  ...  FREESHIP        0  REG100003
# 4      0.00      Carlos    4279.680  ...    SAVE10        0  REG100004
#
#   CustomerName ShippingCost  OrderDate DeliveryDate RegionManager  \
# ...

# %%
df['revenue_in_rupees']=df['revenue']*150.34

# %%
df.head()
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 0 2023-02-23     East  Laptop        14     163.60       Store B    Wholesale
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
# 4 2023-06-24     East    Desk        18     237.76       Store C       Retail
#
#    Discount Salesperson  TotalPrice  ... Returned    OrderID  CustomerName  \
# 0      0.00         Eva    2290.400  ...        0  REG100000     Cust 6583
# 1      0.00       Alice     544.010  ...        0  REG100001     Cust 2144
# 2      0.10       Alice    4361.868  ...        0  REG100002     Cust 5998
# 3      0.15       Frank    5887.746  ...        0  REG100003     Cust 7136
# 4      0.00      Carlos    4279.680  ...        0  REG100004     Cust 6506
#
# ...

# %%
df.drop(columns=['OrderID','CustomerName'], inplace=True)

# %%
df.head()
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 0 2023-02-23     East  Laptop        14     163.60       Store B    Wholesale
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
# 4 2023-06-24     East    Desk        18     237.76       Store C       Retail
#
#    Discount Salesperson  TotalPrice PaymentMethod Promotion  Returned  \
# 0      0.00         Eva    2290.400        Online  FREESHIP         0
# 1      0.00       Alice     544.010     Gift Card    SAVE10         0
# 2      0.10       Alice    4361.868        Online  WINTER15         0
# 3      0.15       Frank    5887.746     Gift Card  FREESHIP         0
# 4      0.00      Carlos    4279.680        Online    SAVE10         0
#
# ...

# %%
del(df['RegionManager'])

# %%
df.head()
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 0 2023-02-23     East  Laptop        14     163.60       Store B    Wholesale
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
# 4 2023-06-24     East    Desk        18     237.76       Store C       Retail
#
#    Discount Salesperson  TotalPrice PaymentMethod Promotion  Returned  \
# 0      0.00         Eva    2290.400        Online  FREESHIP         0
# 1      0.00       Alice     544.010     Gift Card    SAVE10         0
# 2      0.10       Alice    4361.868        Online  WINTER15         0
# 3      0.15       Frank    5887.746     Gift Card  FREESHIP         0
# 4      0.00      Carlos    4279.680        Online    SAVE10         0
#
#    ShippingCost  OrderDate DeliveryDate  product_total_price  revenue  \
# ...

# %%
df.drop(index=0)
# Out:
#            Date   Region  Product  Quantity  UnitPrice StoreLocation  \
# 1    2024-12-19    South    Phone         1     544.01       Store A
# 2    2023-05-10    North     Desk        14     346.18       Store B
# 3    2025-02-26  Central    Chair        18     384.82       Store A
# 4    2023-06-24     East     Desk        18     237.76       Store C
# 5    2024-02-20  Central  Monitor         2     385.09       Store D
# ...         ...      ...      ...       ...        ...           ...
# 1495 2025-02-17     West     Desk        13     134.56       Store D
# 1496 2024-01-11    South    Chair        18     209.75       Store C
# 1497 2024-07-27     East     Desk         1     272.50       Store A
# 1498 2024-12-03  Central  Monitor        14     262.67       Store A
# 1499 2025-05-09     West    Chair        13     221.39       Store D
#
#      CustomerType  Discount Salesperson  TotalPrice PaymentMethod Promotion  \
# ...

# %%
df.drop(index=[1,2])
# Out:
#            Date   Region  Product  Quantity  UnitPrice StoreLocation  \
# 0    2023-02-23     East   Laptop        14     163.60       Store B
# 3    2025-02-26  Central    Chair        18     384.82       Store A
# 4    2023-06-24     East     Desk        18     237.76       Store C
# 5    2024-02-20  Central  Monitor         2     385.09       Store D
# 6    2023-01-11    South    Chair         7      17.50       Store C
# ...         ...      ...      ...       ...        ...           ...
# 1495 2025-02-17     West     Desk        13     134.56       Store D
# 1496 2024-01-11    South    Chair        18     209.75       Store C
# 1497 2024-07-27     East     Desk         1     272.50       Store A
# 1498 2024-12-03  Central  Monitor        14     262.67       Store A
# 1499 2025-05-09     West    Chair        13     221.39       Store D
#
#      CustomerType  Discount Salesperson  TotalPrice PaymentMethod Promotion  \
# ...

# %%
df.dtypes
# Out:
# Date                   datetime64[us]
# Region                            str
# Product                           str
# Quantity                        int64
# UnitPrice                     float64
# StoreLocation                     str
# CustomerType                      str
# Discount                      float64
# Salesperson                       str
# TotalPrice                    float64
# PaymentMethod                     str
# Promotion                         str
# Returned                        int64
# ShippingCost                  float64
# OrderDate              datetime64[us]
# DeliveryDate           datetime64[us]
# product_total_price           float64
# revenue                       float64
# revenue_in_rupees             float64
# dtype: object

# %%
# df['UnitPrice'] = df['UnitPrice'].astype(str)
# df['Quantity'] = df['Quantity'].astype(str)

# %%
# df.dtypes

# %%
df.describe()
# Out:
#                              Date     Quantity    UnitPrice     Discount  \
# count                        1500  1500.000000  1500.000000  1500.000000
# mean   2024-04-07 21:35:02.400000    10.410667   298.826947     0.073133
# min           2023-01-01 00:00:00     1.000000     5.520000     0.000000
# 25%           2023-08-20 00:00:00     5.000000   151.020000     0.000000
# 50%           2024-04-08 12:00:00    11.000000   294.740000     0.050000
# 75%           2024-12-07 06:00:00    15.000000   446.702500     0.100000
# max           2025-06-30 00:00:00    20.000000   599.720000     0.150000
# std                           NaN     5.735732   169.100075     0.055979
#
#          TotalPrice     Returned  ShippingCost                   OrderDate  \
# count   1500.000000  1500.000000   1500.000000                        1500
# mean    2919.994952     0.248000     27.507293  2024-04-07 21:35:02.400000
# min        6.970000     0.000000      5.010000         2023-01-01 00:00:00
# ...

# %%
df[['UnitPrice','TotalPrice']].describe()
# Out:
#          UnitPrice    TotalPrice
# count  1500.000000   1500.000000
# mean    298.826947   2919.994952
# std     169.100075   2522.789977
# min       5.520000      6.970000
# 25%     151.020000    867.136250
# 50%     294.740000   2174.724000
# 75%     446.702500   4414.723500
# max     599.720000  11077.000000

# %%
df.loc[1:3]
# Out:
#         Date   Region Product  Quantity  UnitPrice StoreLocation CustomerType  \
# 1 2024-12-19    South   Phone         1     544.01       Store A       Retail
# 2 2023-05-10    North    Desk        14     346.18       Store B    Wholesale
# 3 2025-02-26  Central   Chair        18     384.82       Store A    Wholesale
#
#    Discount Salesperson  TotalPrice PaymentMethod Promotion  Returned  \
# 1      0.00       Alice     544.010     Gift Card    SAVE10         0
# 2      0.10       Alice    4361.868        Online  WINTER15         0
# 3      0.15       Frank    5887.746     Gift Card  FREESHIP         0
#
#    ShippingCost  OrderDate DeliveryDate  product_total_price  revenue  \
# 1          5.30 2024-12-19   2024-12-28               544.01   538.71
# 2         20.46 2023-05-10   2023-05-19              4846.52  4825.96
# 3         27.95 2025-02-26   2025-03-02              6926.76  6898.66
#
#    revenue_in_rupees
# 1       8.098966e+04
# 2       7.255348e+05
# ...

# %%
df.loc[2,'Product']
# Out:
# 'Desk'

# %%
df.iloc[2,2]
# Out:
# 'Desk'

# %%
df.loc[2,'UnitPrice']
# Out:
# np.float64(346.18)

# %%
df.iloc[2,4]
# Out:
# np.float64(346.18)

# %%
df[df['Promotion'].isnull()]
# Out:
#            Date   Region  Product  Quantity  UnitPrice StoreLocation  \
# 5    2024-02-20  Central  Monitor         2     385.09       Store D
# 7    2023-01-09  Central    Chair         3     330.22       Store C
# 10   2024-04-10    North     Desk        15     523.29       Store B
# 11   2024-07-12     East    Phone        19     207.35       Store D
# 13   2025-01-18     West   Tablet         1     157.83       Store A
# ...         ...      ...      ...       ...        ...           ...
# 1466 2023-12-17    South  Monitor         9      55.04       Store B
# 1472 2025-06-30    South    Phone        20     444.77       Store B
# 1480 2024-08-16     West  Printer        16     483.37       Store B
# 1481 2025-05-30    North  Monitor         6     159.53       Store A
# 1489 2024-11-27    South    Phone        13     196.80       Store B
#
#      CustomerType  Discount Salesperson  TotalPrice PaymentMethod Promotion  \
# ...

# %%
df['Promotion'] = df['Promotion'].fillna('NOT_APPLICABLE')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 1500 non-null   datetime64[us]
#  1   Region               1500 non-null   str
#  2   Product              1500 non-null   str
#  3   Quantity             1500 non-null   int64
#  4   UnitPrice            1500 non-null   float64
#  5   StoreLocation        1500 non-null   str
#  6   CustomerType         1500 non-null   str
#  7   Discount             1500 non-null   float64
#  8   Salesperson          1500 non-null   str
#  9   TotalPrice           1500 non-null   float64
#  10  PaymentMethod        1500 non-null   str
#  11  Promotion            1500 non-null   str
#  12  Returned             1500 non-null   int64
#  13  ShippingCost         1500 non-null   float64
#  14  OrderDate            1500 non-null   datetime64[us]
# ...
