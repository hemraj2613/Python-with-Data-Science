# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.DataFrame(
    {
    'Height':[2,1,5,4,7],
    'Weight':[29,10,58,43,72],
    }
)

# %%
df
# Out:
#    Height  Weight
# 0       2      29
# 1       1      10
# 2       5      58
# 3       4      43
# 4       7      72

# %%
plt.scatter(df['Height'],df['Weight'])

# %%
df.corr()
# Out:
#          Height   Weight
# Height  1.00000  0.98689
# Weight  0.98689  1.00000

# %%
df = pd.DataFrame(
    {
        "HouseSize":[3,4,5,6,7,9],
        "Price":[150,180,210,250,290,320]
    }
)

# %%
plt.scatter(df['HouseSize'],df['Price'])

# %%
df = pd.DataFrame(
    {
        "HouseSize":[3,4,6,7],
        "Price":[4.5,6,9,10.5]
    }
)

# %%
plt.scatter(df['HouseSize'],df['Price'])

# %%
df = pd.DataFrame(
    {
        "HouseSize":[3,4,5,6,7,9],
        "Price":[150,180,210,250,290,320]
    }
)

# %%
df
# Out:
#    HouseSize  Price
# 0          3    150
# 1          4    180
# 2          5    210
# 3          6    250
# 4          7    290
# 5          9    320

# %%
m = 30
c= 2

# %%
df['T1'] = m * df['HouseSize'] + c

# %%
df
# Out:
#    HouseSize  Price   T1
# 0          3    150   92
# 1          4    180  122
# 2          5    210  152
# 3          6    250  182
# 4          7    290  212
# 5          9    320  272

# %%
error1 = abs(df['HouseSize']-df['T1'])

# %%
error1
# Out:
# 0     89
# 1    118
# 2    147
# 3    176
# 4    205
# 5    263
# dtype: int64

# %%
sum(error1)
# Out:
# 998

# %%
m = 35
c = 2

# %%
df['T2'] = m * df['HouseSize'] + c

# %%
df
# Out:
#    HouseSize  Price   T1   T2
# 0          3    150   92  107
# 1          4    180  122  142
# 2          5    210  152  177
# 3          6    250  182  212
# 4          7    290  212  247
# 5          9    320  272  317

# %%
error2 = abs(df['HouseSize']-df['T2'])

# %%
error2
# Out:
# 0    104
# 1    138
# 2    172
# 3    206
# 4    240
# 5    308
# dtype: int64

# %%
sum(error2)
# Out:
# 1168

# %%
m = 38
c = 1

# %%
df['T3'] = m * df['HouseSize'] + c

# %%
df
# Out:
#    HouseSize  Price   T1   T2   T3
# 0          3    150   92  107  115
# 1          4    180  122  142  153
# 2          5    210  152  177  191
# 3          6    250  182  212  229
# 4          7    290  212  247  267
# 5          9    320  272  317  343

# %%
error3 = abs(df['HouseSize']-df['T3'])

# %%
error3
# Out:
# 0    112
# 1    149
# 2    186
# 3    223
# 4    260
# 5    334
# dtype: int64

# %%
sum(error3)
# Out:
# 1264

# %%
# m = 30
# c= 1

# %%
# df['T4'] = m * df['HouseSize'] + c

# %%
# df

# %%
# error4 = abs(df['HouseSize']-df['T4'])

# %%
# error4

# %%
# sum(error4)

# %%
df
# Out:
#    HouseSize  Price   T1   T2   T3
# 0          3    150   92  107  115
# 1          4    180  122  142  153
# 2          5    210  152  177  191
# 3          6    250  182  212  229
# 4          7    290  212  247  267
# 5          9    320  272  317  343

# %%
sns.lineplot(data=df, x='HouseSize', y='Price', marker = "o",  markersize=10,)
sns.lineplot(data=df, x='HouseSize', y='T1',  marker = "o")
sns.lineplot(data=df, x='HouseSize', y='T2',  marker = "o")
sns.lineplot(data=df, x='HouseSize', y='T3',  marker = "o")
# Out:
# <Axes: xlabel='HouseSize', ylabel='Price'>

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
# bad fit

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x,y)

def myfunc(x):
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(10)

print(speed)
print(r)
print(p)
# Out:
# 85.59308314937454
# -0.7585915243761551
# 0.0026468739224561016
